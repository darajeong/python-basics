# %% [markdown]
# ### 정다라 (54/76)
#
# # 파이썬 기초 문제지 — 문항·정답·해설
#
# # 문제지 A형
#
# ## 1번O
#
# **[단답형]** 프로그래밍을 초보자 관점에서 한 문장으로
# 설명할 때, 이 강의에서 강조한 핵심 표현을 쓰시오.
#
# **정답:** 프로그래밍은 문제를 해결하기 위해 컴퓨터가 실행할 명령을 만드는 과정이다.
#
# **해설:** 프로그래밍의 핵심은 해결할 문제를 정하고 컴퓨터가 수행할 명령으로 표현하는 것입니다.
#
#
# ---
#
# ## 2번O
#
# **[다중선택]** 다음 중 AI 시대에 사람이 직접 담당해야 할
# 역할을 모두 고르시오.
# - [ ] ① 무엇을 해결할지 결정한다.
# - [ ] ② AI가 만든 코드의 결과가 맞는지 판단한다.
# - [ ] ③ 모든 코드를 AI가 작성하도록 맡긴다.
# - [ ] ④ 오류 원인을 확인하고 최종 결정을 내린다.
# - [ ] ⑤ 이해하지 못한 코드를 실행하지 않고 제출한다.
#
# **정답:** ①, ②, ④
#
# **해설:** 사람은 문제 정의, 결과 검증, 오류 판단과 최종 결정을 담당해야 합니다.
#
# ---
#
# ## 3번O
#
# **[단답형]** VS Code에서 작성한 파이썬 코드를 실제로 읽고
# 실행하는 프로그램을 무엇이라고 하는가?
#
# **정답:** Python 인터프리터(실행기)
#
# **해설:** 인터프리터가 작성된 파이썬 코드를 읽고 실행합니다.
#
# ---
#
# ## 4번O
#
# **[다중선택]** `python --version`이 정상 동작하지 않을 때의
# 점검 방법으로 적절한 것을 모두 고르시오.
# - [ ] ① 현재 터미널의 오류 메시지를 확인한다.
# - [ ] ② Windows에서 `py --version`도 확인해 본다.
# - [ ] ③ 무조건 운영체제를 재설치한다.
# - [ ] ④ Python 설치 후 새 터미널을 열어 다시 확인한다.
# - [ ] ⑤ VS Code만 설치되어 있으면 Python 설치 여부는
# 확인할 필요가 없다.
#
# **정답:** ①, ②, ④
#
# **해설:** 오류 확인, Windows의 py 명령 확인, 새 터미널 실행이 적절한 점검 방법입니다.
#
# ---
#
# ## 5번X
#
# **[단답형]** AI에게 오류 해결을 질문할 때 코드와 함께
# 반드시 전달해야 할 핵심 정보 중 하나로, 실제로 화면에
# 나타난 오류 내용을 무엇이라고 하는가?
#
# **정답:** 오류 메시지
#
# **해설:** 실제 오류 메시지는 문제의 종류와 원인을 찾는 핵심 단서입니다.
#
# ---
#
# ## 6번O
#
# **[다중선택]** 학습용 코딩 질문을 더 정확하게 만드는
# 정보로 적절한 것을 모두 고르시오.
# - [ ] ① 나의 현재 수준
# - [ ] ② 구현하려는 목표
# - [ ] ③ 실제 코드와 실행 결과
# - [ ] ④ 원하는 도움의 형태
# - [ ] ⑤ API 키와 비밀번호 원문
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 수준·목표·코드와 결과·원하는 도움을 알려야 정확한 답을 받을 수 있으며 민감정보는 제외합니다.
#
# ---
#
# ## 7번X
#
# **[단답형]** 다음 코드의 출력 결과를 그대로 쓰시오.
# `print("Python", 100)`
#
# **정답:** Python 100
#
# **해설:** print()의 두 값은 기본적으로 공백으로 구분되어 출력됩니다.
#
# ---
#
# ## 8번O
#
# **[다중선택]** 다음 중 Chapter 04에서 배운 파이썬 기본
# 규칙으로 맞는 것을 모두 고르시오.
# - [ ] ① 문자열은 따옴표로 감쌀 수 있다.
# - [ ] ② `#` 뒤의 내용은 주석으로 사용할 수 있다.
# - [ ] ③ 파이썬 코드는 기본적으로 위에서 아래로 실행된다.
# - [ ] ④ 들여쓰기는 언제나 보기 좋게 만드는 장식일 뿐이다.
# - [ ] ⑤ `print()` 안에 여러 값을 쉼표로 나누어 넣을 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 문자열, 주석, 실행 순서, print()의 쉼표 사용은 기본 규칙이며 들여쓰기는 문법적 의미가 있습니다.
#
# ---
#
# ## 9번O
#
# **[단답형]** 다음 값의 데이터형 이름을 쓰시오.
# age = "20"
#
# **정답:** str(문자열)
#
# **해설:** 따옴표로 감싼 20은 숫자가 아니라 문자열입니다.
#
# ---
#
# ## 10번X
#
# **[다중선택]** 다음 중 변수와 데이터형에 대한 설명으로
# 맞는 것을 모두 고르시오.
# - [ ] ① `score = 80` 뒤에 `score = 95`를 실행하면 현재 score
# 값은 95이다.
# - [ ] ② `type()`으로 값의 데이터형을 확인할 수 있다.
# - [ ] ③ `int("25")`는 정수 25로 변환할 수 있다.
# - [ ] ④ `int("스물")`은 정상적으로 정수 20이 된다.
# - [ ] ⑤ 변수 이름에는 값의 의미가 드러나도록 작성하는
# 것이 좋다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 변수는 재대입할 수 있고 type()과 형 변환을 사용할 수 있지만 '스물'은 int로 바꿀 수 없습니다.
#
# ---
#
# ## 11번O
#
# **[단답형]** 다음 두 식의 결과를 순서대로 쓰시오.
# 17 // 5
# 17 % 5
#
# **정답:** 3, 2
#
# **해설:** //는 몫, %는 나머지를 구합니다.
#
# ---
#
# ## 12번O
#
# **[다중선택]** 다음 중 연산 결과가 올바른 것을 모두
# 고르시오.
# - [ ] ① `2 ** 3` → 8
# - [ ] ② `10 / 2` → 5.0
# - [ ] ③ `17 % 5` → 2
# - [ ] ④ `3 > 5` → True
# - [ ] ⑤ `10 != 7` → True
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 2의 3제곱은 8, /의 결과는 5.0, 나머지는 2이며 10과 7은 같지 않습니다.
#
# ---
#
# ## 13번X
#
# **[단답형]** 다음 코드의 결과를 쓰시오.
# text = "Python"
# `print(text[1:4])`
#
# **정답:** yth
#
# **해설:** 슬라이스 [1:4]는 인덱스 1부터 3까지 가져옵니다.
#
# ---
#
# ## 14번X
#
# **[다중선택]** 다음 중 문자열 처리에 사용할 수 있는
# 기능을 모두 고르시오.
# - [ ] ① `strip()`로 앞뒤 공백 제거
# - [ ] ② `replace()`로 일부 문자열 치환
# - [ ] ③ `upper()`로 대문자 변환
# - [ ] ④ `append()`로 문자열 끝에 문자 추가
# - [ ] ⑤ `len()`으로 문자열 길이 확인
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 문자열에는 strip·replace·upper와 len을 쓸 수 있지만 append는 리스트 메서드입니다.
#
# ---
#
# ## 15번O
#
# **[단답형]** `input()`으로 입력받은 값의 기본 데이터형을
# 쓰시오.
#
# **정답:** str(문자열)
#
# **해설:** input()은 입력 내용을 항상 문자열로 반환합니다.
#
# ---
#
# ## 16번O
#
# **[다중선택]** 사용자 입력을 이용한 프로그램에 대한
# 설명으로 맞는 것을 모두 고르시오.
# - [ ] ① 숫자 계산이 필요하면 `int()`나 `float()` 변환을
# 고려한다.
# - [ ] ② `strip()`으로 입력 문자열의 앞뒤 공백을 정리할 수
# 있다.
# - [ ] ③ `input()`은 사용자가 값을 입력할 때까지 기다린다.
# - [ ] ④ `input()`은 숫자를 입력하면 자동으로 int를
# 반환한다.
# - [ ] ⑤ 숫자로 바꿀 수 없는 문자열을 `int()`로 변환하면
# ValueError가 발생할 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 입력은 문자열이므로 계산 전 형 변환이 필요할 수 있고 잘못된 변환은 ValueError를 냅니다.
#
# ---
#
# ## 17번O
#
# **[단답형]** 다음 코드에서 출력되는 문장을 쓰시오.
# score = 60
# if score >= 60:
# `print("통과")`
#
# **정답:** 통과
#
# **해설:** 60은 score >= 60을 만족하므로 통과가 출력됩니다.
#
# ---
#
# ## 18번X
#
# **[다중선택]** 조건문에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① `if`의 조건식이 True일 때 들여쓰기된 코드가
# 실행된다.
# - [ ] ② `if` 뒤에는 콜론(`:`)이 필요하다.
# - [ ] ③ `=`와 `==`는 같은 의미이다.
# - [ ] ④ `elif`를 사용해 여러 조건을 순서대로 검사할 수 있다.
# - [ ] ⑤ 조건이 겹치면 조건의 배치 순서가 결과에 영향을 줄
# 수 있다.
#
# **정답:** ①, ②, ④, ⑤
#
# **해설:** 조건이 참일 때 실행되고 콜론과 정확한 들여쓰기가 필요하며 조건 순서도 결과에 영향을 줍니다.
#
# ---
#
# ## 19번O
#
# **[단답형]** 다음 코드에서 `print(i)`는 몇 번 실행되는가?
# for i in range(5):
# `print(i)`
#
# **정답:** 5번
#
# **해설:** range(5)는 0부터 4까지 다섯 값을 만듭니다.
#
# ---
#
# ## 20번O
#
# **[다중선택]** 반복문에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① `range(5)`는 0,1,2,3,4를 만든다.
# - [ ] ② `break`는 반복문을 즉시 종료할 수 있다.
# - [ ] ③ `continue`는 현재 반복의 남은 부분을 건너뛰고 다음
# 반복으로 진행한다.
# - [ ] ④ `range(0)`은 항상 오류가 발생한다.
# - [ ] ⑤ `while`문은 조건과 상태 변화가 중요하다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** range(0)은 오류가 아니라 빈 범위이며 나머지 설명은 반복 제어의 올바른 특징입니다.
#
# ---
#
# ## 21번O
#
# **[단답형]** 다음 리스트에서 마지막 값을 인덱싱하는
# 표현을 하나 쓰시오.
# fruits = ["사과", "바나나", "포도"]
#
# **정답:** fruits[-1]
#
# **해설:** -1은 시퀀스의 마지막 요소를 가리킵니다.
#
# ---
#
# ## 22번X
#
# **[다중선택]** 리스트에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① `append()`는 리스트 끝에 값을 추가할 수 있다.
# - [ ] ② `sum()`은 숫자 리스트의 합계를 구할 수 있다.
# - [ ] ③ 리스트의 첫 인덱스는 1이다.
# - [ ] ④ 리스트의 특정 요소는 수정할 수 있다.
# - [ ] ⑤ `sort()`로 리스트의 순서를 정렬할 수 있다.
#
# **정답:** ①, ②, ④, ⑤
#
# **해설:** 리스트 인덱스는 0부터 시작하므로 ③만 틀립니다.
#
# ---
#
# ## 23번O
#
# **[단답형]** 요소가 하나인 튜플 `(10,)`에서 튜플임을
# 결정하는 핵심 기호를 쓰시오.
#
# **정답:** 쉼표(,)
#
# **해설:** 요소가 하나일 때 쉼표가 있어야 튜플로 인식됩니다.
#
# ---
#
# ## 24번X
#
# **[다중선택]** 튜플과 집합에 대한 설명으로 맞는 것을
# 모두 고르시오.
# - [ ] ① 튜플은 순서가 있다.
# - [ ] ② 튜플 요소는 직접 수정할 수 없다.
# - [ ] ③ 집합은 중복 값을 제거하는 특징이 있다.
# - [ ] ④ 빈 집합은 `{}`로 만드는 것이 가장 정확하다.
# - [ ] ⑤ 집합에서는 합집합·교집합·차집합을 사용할 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 빈 집합은 {}가 아니라 set()으로 만듭니다.
#
# ---
#
# ## 25번X
#
# **[단답형]** 다음 딕셔너리에서 점수 85를 가져오는 표현을
# 쓰시오.
# student = {"name": "민수", "score": 85}
#
# **정답:** student["score"]
#
# **해설:** 딕셔너리는 키를 대괄호에 넣어 해당 값을 조회합니다.
#
# ---
#
# ## 26번X
#
# **[다중선택]** 딕셔너리에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① 값은 키를 이용해 조회할 수 있다.
# - [ ] ② `get()`은 없는 키를 비교적 안전하게 다루는 데
# 활용할 수 있다.
# - [ ] ③ `items()`는 키와 값을 함께 반복 처리할 때 사용할 수
# 있다.
# - [ ] ④ 딕셔너리는 반드시 숫자 인덱스로만 값을 찾아야
# 한다.
# - [ ] ⑤ `in`으로 키 존재 여부를 확인할 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 딕셔너리는 숫자 인덱스가 아니라 키로 값을 찾습니다.
#
# ---
#
# ## 27번O
#
# **[단답형]** 함수에서 계산 결과를 호출한 곳으로 돌려보낼
# 때 사용하는 키워드를 쓰시오.
#
# **정답:** return
#
# **해설:** return은 함수의 결과를 호출한 곳으로 전달합니다.
#
# ---
#
# ## 28번O
#
# **[다중선택]** 함수에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① 함수는 `def`로 정의할 수 있다.
# - [ ] ② 함수 정의만 해도 함수 본문이 즉시 실행된다.
# - [ ] ③ 매개변수는 함수 정의에서 입력 자리를 나타낸다.
# - [ ] ④ `return`과 `print()`는 항상 같은 역할이다.
# - [ ] ⑤ 긴 코드를 역할별 작은 함수로 나누면 구조를
# 이해하기 쉬워질 수 있다.
#
# **정답:** ①, ③, ⑤
#
# **해설:** 함수 정의만으로 본문이 실행되지는 않으며 return과 print의 역할도 다릅니다.
#
# ---
#
# ## 29번O
#
# **[단답형]** 프로젝트마다 독립된 Python 실행 환경을 만들
# 때 사용하는 표준 기능 이름을 쓰시오.
#
# **정답:** venv(가상환경)
#
# **해설:** venv는 프로젝트별 패키지와 버전을 분리하는 표준 가상환경 기능입니다.
#
# ---
#
# ## 30번X
#
# **[다중선택]** 모듈·패키지·가상환경에 대한 설명으로 맞는
# 것을 모두 고르시오.
# - [ ] ① 모듈은 파이썬 코드를 담은 `.py` 파일이다.
# - [ ] ② 패키지는 관련 모듈을 폴더 구조로 묶을 수 있다.
# - [ ] ③ 표준 라이브러리는 일반적으로 Python과 함께
# 제공된다.
# - [ ] ④ 가상환경을 만들면 모든 프로젝트가 반드시 같은
# 패키지 버전을 사용한다.
# - [ ] ⑤ `requirements.txt`로 필요한 패키지와 버전을 기록할
# 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 가상환경은 프로젝트별로 서로 다른 패키지 버전을 사용할 수 있게 합니다.
#
# ---
#
# ## 31번O
#
# **[단답형]** 파일을 읽기 전용으로 열 때 사용하는 파일
# 모드 문자를 쓰시오.
#
# **정답:** r
#
# **해설:** r은 read의 약자로 읽기 전용 모드입니다.
#
# ---
#
# ## 32번O
#
# **[다중선택]** 파일과 CSV 처리에 대한 설명으로 맞는 것을
# 모두 고르시오.
# - [ ] ① `with open()` 블록이 끝나면 파일이 자동으로 닫힌다.
# - [ ] ② `read()`는 파일 전체 내용을 한 번에 읽을 수 있다.
# - [ ] ③ CSV에서 읽은 숫자 데이터는 필요하면 int/float로
# 변환한다.
# - [ ] ④ `w` 모드는 기존 내용 뒤에 항상 이어 쓰기만 한다.
# - [ ] ⑤ `csv.DictReader`는 열 이름을 키처럼 다루는 데
# 사용할 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** w는 기존 내용을 덮어쓰며 뒤에 추가하는 모드는 a입니다.
#
# ---
#
# ## 33번O
#
# **[단답형]** `int("abc")` 실행 시 발생하는 대표적인 예외
# 이름을 쓰시오.
#
# **정답:** ValueError
#
# **해설:** abc는 정수 형식이 아니므로 값 변환 과정에서 ValueError가 납니다.
#
# ---
#
# ## 34번O
#
# **[다중선택]** 오류와 예외 처리에 대한 설명으로 맞는
# 것을 모두 고르시오.
# - [ ] ① 트레이스백은 마지막 줄의 예외 이름부터 확인하는
# 습관이 유용하다.
# - [ ] ② `try-except`는 모든 논리 오류를 자동으로 수정한다.
# - [ ] ③ 예외 종류별로 여러 `except`를 작성할 수 있다.
# - [ ] ④ `finally`는 정리 작업 등에 활용할 수 있다.
# - [ ] ⑤ 예외 이름 없는 `except:`를 습관적으로 넓게 쓰는
# 것은 권장되지 않는다.
#
# **정답:** ①, ③, ④, ⑤
#
# **해설:** try-except는 예외를 처리하지만 논리 오류를 자동으로 수정하지는 않습니다.
#
# ---
#
# ## 35번O
#
# **[단답형]** 클래스를 이용해 실제로 만든 값을 무엇이라고
# 하는가?
#
# **정답:** 객체 또는 인스턴스
#
# **해설:** 클래스라는 설계도로 실제 생성한 값을 객체 또는 인스턴스라고 합니다.
#
# ---
#
# ## 36번O
#
# **[다중선택]** 클래스와 객체에 대한 설명으로 맞는 것을
# 모두 고르시오.
# - [ ] ① 클래스는 데이터와 기능의 구조를 정의하는
# 설계도처럼 볼 수 있다.
# - [ ] ② `Student()`를 두 번 호출하면 항상 같은 객체가
# 반환된다.
# - [ ] ③ `self`는 현재 객체 자신을 가리킨다.
# - [ ] ④ `__init__()`은 객체 생성 시 초기값을 저장하는 데
# 사용할 수 있다.
# - [ ] ⑤ 단순한 데이터 문제도 언제나 딕셔너리보다
# 클래스가 더 좋다.
#
# **정답:** ①, ③, ④
#
# **해설:** 호출할 때마다 별도 객체가 만들어질 수 있고 단순 문제에 클래스가 언제나 최선인 것은 아닙니다.
#
# ---
#
# ## 37번O
#
# **[단답형]** 프로그램을 설계할 때 Input, Process, Output을
# 묶어 부르는 약어를 쓰시오.
#
# **정답:** IPO
#
# **해설:** IPO는 입력·처리·출력의 영어 머리글자입니다.
#
# ---
#
# ## 38번X
#
# **[다중선택]** AI와 함께 프로그램을 설계할 때 적절한
# 행동을 모두 고르시오.
# - [ ] ① 코드 작성 전에 목적과 범위를 정리한다.
# - [ ] ② 이번에 하지 않을 기능도 명시할 수 있다.
# - [ ] ③ 데이터의 모양을 리스트와 딕셔너리 등으로 먼저
# 생각한다.
# - [ ] ④ 처음부터 전체 프로그램을 AI에게 맡기고 결과만
# 복사한다.
# - [ ] ⑤ 작은 테스트 데이터의 예상 결과와 실제 결과를
# 비교한다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 목적·범위·데이터 구조를 설계하고 작은 예상값으로 결과를 검증해야 합니다.
#
# ---
#
# # 문제지 B형
#
# ## 1번O
#
# **[단답형]** AI 시대의 파이썬 학습 목표를 ‘코드를 ○○하고
# ○○하고 ○○하고 ○○하는 능력’이라는 네 동사로 쓰시오.
#
# **정답:** 읽고, 이해하고, 수정하고, 작성하는 능력
#
# **해설:** AI 시대에도 코드를 스스로 읽고 이해하며 필요에 따라 수정하고 작성하는 능력이 핵심입니다.
#
# ---
#
# ## 2번O
#
# **[다중선택]** 다음 중 AI를 ‘개인 튜터’처럼 사용하는
# 방식으로 적절한 것을 모두 고르시오.
# - [ ] ① 어려운 개념을 더 쉽게 설명해 달라고 한다.
# - [ ] ② 오류 메시지의 의미를 설명해 달라고 한다.
# - [ ] ③ 문제를 읽자마자 전체 완성 코드를 요청한다.
# - [ ] ④ 다음 한 단계의 힌트만 요청한다.
# - [ ] ⑤ AI 답변을 실행하지 않고 정답으로 확정한다.
#
# **정답:** ①, ②, ④
#
# **해설:** AI에는 설명과 힌트를 요청하고 결과는 직접 검증해야 합니다.
#
# ---
#
# ## 3번O
#
# **[단답형]** 터미널에서 설치된 Python 버전을 확인하는
# 대표 명령을 쓰시오.
#
# **정답:** python --version
#
# **해설:** 이 명령은 현재 터미널에서 선택된 Python의 버전을 표시합니다.
#
# ---
#
# ## 4번O
#
# **[다중선택]** 파이썬 개발 환경 구성 요소와 역할의 연결로
# 맞는 것을 모두 고르시오.
# - [ ] ① VS Code - 코드 작성과 파일 관리
# - [ ] ② Python 실행기 - `.py` 코드 실행
# - [ ] ③ Python 확장 - VS Code와 Python 사용을 편리하게
# 연결
# - [ ] ④ Terminal - 명령 실행과 결과 확인
# - [ ] ⑤ Explorer - Python 패키지를 인터넷에서 자동 설치
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 각 도구는 코드 작성, 실행, 편의 기능 연결, 명령 실행을 담당하며 Explorer가 패키지를 자동 설치하지는 않습니다.
#
# ---
#
# ## 5번O
#
# **[단답형]** AI에게 질문하기 전에 제거해야 하는 대표적인
# 민감정보를 한 가지 쓰시오.
#
# **정답:** 비밀번호, API 키, 주민등록번호 등의 민감정보 중 하나
#
# **해설:** 민감정보는 질문 전에 삭제하거나 가상의 값으로 바꿔야 합니다.
#
# ---
#
# ## 6번O
#
# **[다중선택]** 다음 중 ‘정답 코드보다 학습을 돕는 질문’에
# 해당하는 것을 모두 고르시오.
# - [ ] ① 왜 이 오류가 생겼는지 먼저 설명해 줘.
# - [ ] ② 완성 코드는 주지 말고 첫 번째 힌트만 알려 줘.
# - [ ] ③ 내 코드와 오류 메시지를 보고 원인을 단계별로
# 설명해 줘.
# - [ ] ④ 아무 설명 없이 최종 정답 코드만 줘.
# - [ ] ⑤ 내 수준에 맞게 어려운 문법은 피해서 설명해 줘.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 원인 설명·단계별 힌트·수준에 맞는 설명은 학습을 돕습니다.
#
# ---
#
# ## 7번O
#
# **[단답형]** 파이썬에서 한 줄 주석을 시작할 때 사용하는
# 기호를 쓰시오.
#
# **정답:** #
#
# **해설:** # 뒤의 내용은 한 줄 주석으로 처리됩니다.
#
# ---
#
# ## 8번X
#
# **[다중선택]** 다음 코드에서 오류를 만들 가능성이 있는
# 변경을 모두 고르시오.
# `print("Hello, Python!")`
# - [ ] ① 닫는 괄호 `)`를 삭제한다.
# - [ ] ② 시작 큰따옴표만 삭제한다.
# - [ ] ③ 문자열 내용을 `Hi`로 바꾼다.
# - [ ] ④ `print`를 그대로 두고 문자열만 한글로 바꾼다.
# - [ ] ⑤ 괄호 안 문자열의 끝 따옴표만 삭제한다.
#
# **정답:** ①, ②, ⑤
#
# **해설:** 괄호나 따옴표 한쪽을 삭제하면 문법 오류가 생길 수 있습니다.
#
# ---
#
# ## 9번
#
# **[단답형]** `int("3.14")`을 그대로 실행하면 발생하는
# 대표적인 예외 이름을 쓰시오.
#
# **정답:** ValueError
#
# **해설:** 3.14는 정수 형식 문자열이 아니어서 int()로 직접 변환할 수 없습니다.
#
# ---
#
# ## 10번X
#
# **[다중선택]** 다음 중 실행 후 데이터형 설명이 맞는 것을
# 모두 고르시오.
# - [ ] ① `int("25")` → int
# - [ ] ② `float("3.5")` → float
# - [ ] ③ `str(100)` → str
# - [ ] ④ `bool(0)` → bool
# - [ ] ⑤ `int("hello")` → int
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 앞의 네 표현은 실제 반환 자료형이 각각 설명과 같고 int('hello')는 예외를 냅니다.
#
# ---
#
# ## 11번O
#
# **[단답형]** 다음 식의 결과를 쓰시오.
# 2 ** 3 + 1
#
# **정답:** 9
#
# **해설:** 거듭제곱을 먼저 계산하여 8 + 1 = 9입니다.
#
# ---
#
# ## 12번O
#
# **[다중선택]** 다음 중 비교 또는 논리 연산의 결과가
# True인 것을 모두 고르시오.
# - [ ] ① `10 >= 10`
# - [ ] ② `5 != 5`
# - [ ] ③ `3 < 7 and 2 < 4`
# - [ ] ④ `3 > 7 or 10 == 10`
# - [ ] ⑤ `not True`
#
# **정답:** ①, ③, ④
#
# **해설:** 각 식을 평가하면 ①·③·④만 True입니다.
#
# ---
#
# ## 13번O
#
# **[단답형]** 다음 코드의 결과를 쓰시오.
# word = "Python"
# `print(word[-1])`
#
# **정답:** n
#
# **해설:** 인덱스 -1은 마지막 문자인 n을 가리킵니다.
#
# ---
#
# ## 14번X
#
# **[다중선택]** 다음 중 문자열 처리 코드로 올바른 것을
# 모두 고르시오.
# - [ ] ① `" python ".strip()`은 앞뒤 공백을 제거한다.
# - [ ] ② `"Python".lower()`는 소문자 문자열을 만든다.
# - [ ] ③ `"banana".count("a")`는 특정 문자의 개수를 셀 수
# 있다.
# - [ ] ④ 존재하지 않는 인덱스를 사용하면 IndexError가 날 수
# 있다.
# - [ ] ⑤ 문자열의 한 글자는 리스트처럼 직접 대입해 수정할
# 수 있다.
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 문자열은 불변이므로 한 글자에 직접 대입할 수 없습니다.
#
# ---
#
# ## 15번O
#
# **[단답형]** 사용자가 `12`를 입력했다고 할 때 다음 코드의
# 출력값을 쓰시오.
# age = int(input("나이: "))
# `print(age + 1)`
#
# **정답:** 13
#
# **해설:** 입력 12를 정수로 바꾸고 1을 더하므로 13입니다.
#
# ---
#
# ## 16번X
#
# **[다중선택]** 다음 중 `input()` 사용 시 발생 가능한 문제와
# 대응으로 맞는 것을 모두 고르시오.
# - [ ] ① 숫자 계산 전에 필요한 경우 형 변환한다.
# - [ ] ② 앞뒤 공백이 문제라면 `strip()`을 사용할 수 있다.
# - [ ] ③ `int("abc")`는 ValueError가 날 수 있다.
# - [ ] ④ `input()` 반환값은 항상 float이므로 int 변환은
# 불필요하다.
# - [ ] ⑤ 여러 번 input()을 호출해 서로 다른 변수에 저장할 수
# 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** input()의 반환값은 항상 문자열이며 필요한 경우 여러 번 호출할 수 있습니다.
#
# ---
#
# ## 17번O
#
# **[단답형]** 다음 코드에서 출력되는 문장을 쓰시오.
# score = 75
# if score >= 90:
# `print("A")`
# elif score >= 75:
# `print("B")`
# else:
# `print("C")`
#
# **정답:** B
#
# **해설:** 75는 첫 조건은 거짓이지만 elif 조건을 만족해 B가 출력됩니다.
#
# ---
#
# ## 18번X
#
# **[다중선택]** 조건문을 안전하게 작성하는 방법으로 맞는
# 것을 모두 고르시오.
# - [ ] ① 조건식의 경계값을 직접 테스트한다.
# - [ ] ② 겹치는 조건이 있으면 검사 순서를 확인한다.
# - [ ] ③ 조건 비교에는 항상 `=`를 사용한다.
# - [ ] ④ 복합 조건에는 `and`, `or`, `not`을 사용할 수 있다.
# - [ ] ⑤ 들여쓰기 수준이 올바른지 확인한다.
#
# **정답:** ①, ②, ④, ⑤
#
# **해설:** 경계값·조건 순서·복합 조건·들여쓰기를 점검해야 하며 비교에는 ==를 사용합니다.
#
# ---
#
# ## 19번X
#
# **[단답형]** 다음 코드의 최종 `total` 값을 쓰시오.
# total = 0
# for n in range(1, 4):
# total += n
#
# **정답:** 6
#
# **해설:** range(1, 4)의 1, 2, 3을 더하면 6입니다.
#
# ---
#
# ## 20번O
#
# **[다중선택]** 반복문에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① `for`문은 반복할 값들을 하나씩 꺼내 처리할 수 있다.
# - [ ] ② `while`문에서 상태가 변하지 않으면 무한 반복이 될
# 수 있다.
# - [ ] ③ `continue`는 반복문 전체를 완전히 종료한다.
# - [ ] ④ 반복문 안에 조건문을 함께 사용할 수 있다.
# - [ ] ⑤ 중첩 반복문은 바깥 반복과 안쪽 반복의 실행 순서를
# 추적해야 한다.
#
# **정답:** ①, ②, ④, ⑤
#
# **해설:** continue는 전체 종료가 아니라 현재 반복의 남은 부분만 건너뜁니다.
#
# ---
#
# ## 21번O
#
# **[단답형]** 다음 코드 실행 후 리스트를 쓰시오.
# nums = [1, 2]
# nums.append(3)
# `print(nums)`
#
# **정답:** [1, 2, 3]
#
# **해설:** append(3)은 리스트 끝에 3을 추가합니다.
#
# ---
#
# ## 22번O
#
# **[다중선택]** 리스트 상태를 확인하거나 변경하는
# 기능으로 맞는 것을 모두 고르시오.
# - [ ] ① `len()` - 요소 개수 확인
# - [ ] ② `in` - 값 포함 여부 확인
# - [ ] ③ `pop()` - 요소 삭제 및 반환
# - [ ] ④ `index()` - 값의 위치 찾기
# - [ ] ⑤ `keys()` - 리스트의 모든 인덱스 반환
#
# **정답:** ①, ②, ③, ④
#
# **해설:** keys()는 리스트가 아니라 딕셔너리의 키를 확인하는 메서드입니다.
#
# ---
#
# ## 23번O
#
# **[단답형]** 빈 집합을 만드는 파이썬 표현을 쓰시오.
#
# **정답:** set()
#
# **해설:** {}는 빈 딕셔너리이므로 빈 집합은 set()으로 만듭니다.
#
# ---
#
# ## 24번X
#
# **[다중선택]** 상황에 맞는 자료구조 선택으로 적절한 것을
# 모두 고르시오.
# - [ ] ① 값의 순서와 수정이 모두 중요하면 리스트를
# 고려한다.
# - [ ] ② 한 번 정한 값의 조합을 직접 수정하지 않으려면
# 튜플을 고려한다.
# - [ ] ③ 중복 제거가 중요하면 집합을 고려한다.
# - [ ] ④ 중복을 반드시 유지해야 하는데 집합만 사용한다.
# - [ ] ⑤ 집합은 교집합을 구하는 데 사용할 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 집합은 중복을 제거하므로 중복을 반드시 유지할 때는 적합하지 않습니다.
#
# ---
#
# ## 25번O
#
# **[단답형]** 없는 키를 조회할 때 KeyError를 피하기 위해
# 활용할 수 있는 딕셔너리 메서드 이름을 쓰시오.
#
# **정답:** get()
#
# **해설:** get()은 키가 없을 때 KeyError 대신 None 또는 지정한 기본값을 반환합니다.
#
# ---
#
# ## 26번O
#
# **[다중선택]** 다음 중 딕셔너리 처리로 맞는 것을 모두
# 고르시오.
# - [ ] ① 새 키에 값을 대입해 항목을 추가할 수 있다.
# - [ ] ② 기존 키에 새 값을 대입해 수정할 수 있다.
# - [ ] ③ `keys()`는 키들을 확인하는 데 사용할 수 있다.
# - [ ] ④ `values()`는 값들을 확인하는 데 사용할 수 있다.
# - [ ] ⑤ 딕셔너리는 같은 키를 여러 개 독립 항목으로 그대로
# 유지한다.
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 딕셔너리의 키는 중복될 수 없으므로 같은 키에 대입하면 기존 값이 바뀝니다.
#
# ---
#
# ## 27번O
#
# **[단답형]** 함수 정의에서 값을 받아들이는 이름을
# 무엇이라고 하는가?
#
# **정답:** 매개변수(parameter)
#
# **해설:** 함수 정의에서 입력값을 받을 자리를 매개변수라고 합니다.
#
# ---
#
# ## 28번O
#
# **[다중선택]** 함수 설계에 대한 설명으로 맞는 것을 모두
# 고르시오.
# - [ ] ① 함수 이름은 역할이 드러나도록 작성하는 것이 좋다.
# - [ ] ② 함수 안의 지역 변수는 일반적으로 함수 밖에서
# 그대로 사용할 수 없다.
# - [ ] ③ 기본값 매개변수를 사용할 수 있다.
# - [ ] ④ 키워드 인수로 인수 이름을 명시할 수 있다.
# - [ ] ⑤ 모든 함수는 반드시 화면에 값을 print해야 한다.
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 함수는 반드시 print할 필요가 없으며 return으로 결과를 돌려줄 수도 있습니다.
#
# ---
#
# ## 29번O
#
# **[단답형]** 설치된 패키지 목록을 다른 환경에서 재현하기
# 위해 프로젝트에 기록하는 대표 파일 이름을 쓰시오.
#
# **정답:** requirements.txt
#
# **해설:** requirements.txt에 패키지와 버전을 기록해 다른 환경에서 재설치할 수 있습니다.
#
# ---
#
# ## 30번O
#
# **[다중선택]** `ModuleNotFoundError`가 발생했을 때
# 확인할 사항으로 적절한 것을 모두 고르시오.
# - [ ] ① 모듈 파일의 위치와 이름
# - [ ] ② 현재 선택된 Python 인터프리터
# - [ ] ③ 패키지가 현재 가상환경에 설치되어 있는지
# - [ ] ④ 무조건 모든 패키지를 전역 환경에 설치
# - [ ] ⑤ VS Code가 프로젝트의 `.venv`를 사용하고 있는지
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 모듈 경로, 인터프리터, 현재 가상환경의 설치 여부를 확인해야 하며 무조건 전역 설치할 필요는 없습니다.
#
# ---
#
# ## 31번O
#
# **[단답형]** 기존 파일 내용 뒤에 새 내용을 추가할 때
# 사용하는 파일 모드 문자를 쓰시오.
#
# **정답:** a
#
# **해설:** a는 append의 약자로 기존 내용 끝에 이어 씁니다.
#
# ---
#
# ## 32번X
#
# **[다중선택]** CSV 데이터를 처리할 때 필요한 행동으로
# 맞는 것을 모두 고르시오.
# - [ ] ① 열 이름을 기준으로 읽고 싶으면 DictReader를
# 고려한다.
# - [ ] ② 숫자 열이 문자열이라면 계산 전 형 변환한다.
# - [ ] ③ 파일 경로가 맞는지 확인한다.
# - [ ] ④ FileNotFoundError가 나도 경로는 확인할 필요가
# 없다.
# - [ ] ⑤ 반복문으로 여러 행을 처리해 합계나 평균을 계산할
# 수 있다.
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** CSV 처리에서는 열 구조, 자료형, 경로를 확인하고 반복문으로 여러 행을 집계할 수 있습니다.
#
# ---
#
# ## 33번O
#
# **[단답형]** 트레이스백을 처음 읽을 때 우선 확인하는
# 마지막 줄의 핵심 두 정보는 무엇인가?
#
# **정답:** 예외 이름과 오류 메시지
#
# **해설:** 마지막 줄의 예외 이름은 종류를, 메시지는 구체적인 원인을 알려 줍니다.
#
# ---
#
# ## 34번X
#
# **[다중선택]** 다음 중 실행 중 예외의 예로 적절한 것을
# 모두 고르시오.
# - [ ] ① `int("스물")`의 ValueError
# - [ ] ② 0으로 나누기의 ZeroDivisionError
# - [ ] ③ 없는 파일 열기의 FileNotFoundError
# - [ ] ④ 콜론 누락으로 인한 SyntaxError
# - [ ] ⑤ 없는 딕셔너리 키 접근의 KeyError
#
# **정답:** ①, ②, ③, ⑤
#
# **해설:** 콜론 누락의 SyntaxError는 실행 중 예외라기보다 코드 실행 전 문법 분석 단계의 오류입니다.
#
# ---
#
# ## 35번O
#
# **[단답형]** 객체 생성 시 초기값을 저장하는 데 주로
# 사용하는 특별 메서드 이름을 쓰시오.
#
# **정답:** __init__
#
# **해설:** __init__은 객체 생성 시 초기 속성을 설정하는 특별 메서드입니다.
#
# ---
#
# ## 36번O
#
# **[다중선택]** 클래스 사용이 자연스러운 상황을 모두
# 고르시오.
# - [ ] ① 같은 형태의 데이터와 관련 기능이 여러 객체에서
# 반복된다.
# - [ ] ② 상품 객체마다 이름·가격·재고와 관련 메서드가
# 필요하다.
# - [ ] ③ 단순한 값 한 개만 잠시 저장하면 반드시 클래스를
# 써야 한다.
# - [ ] ④ 하나의 클래스로 여러 서로 다른 객체를 만들 수
# 있다.
# - [ ] ⑤ 객체를 리스트에 넣어 반복 처리할 수 있다.
#
# **정답:** ①, ②, ④, ⑤
#
# **해설:** 동일 구조의 여러 객체가 필요할 때 클래스가 유용하며 객체들은 리스트에도 저장할 수 있습니다.
#
# ---
#
# ## 37번O
#
# **[단답형]** 요구사항을 정한 다음 큰 기능을 역할별 작은
# 단위로 나눌 때 Chapter 19에서 권장한 대표 코드 단위를
# 쓰시오.
#
# **정답:** 함수(function)
#
# **해설:** 큰 기능을 역할별 함수로 나누면 이해·수정·테스트가 쉬워집니다.
#
# ---
#
# ## 38번X
#
# **[다중선택]** 학생 점수 요약 프로그램을 설계할 때 코드
# 작성 전에 할 일로 적절한 것을 모두 고르시오.
# - [ ] ① 저장할 데이터의 모양을 정한다.
# - [ ] ② 입력·처리·출력을 구분한다.
# - [ ] ③ 이번 실습에서 하지 않을 범위를 정한다.
# - [ ] ④ 평균의 예상 결과를 작은 테스트 데이터로 미리
# 계산한다.
# - [ ] ⑤ 설계 없이 AI가 만든 최종 코드부터 복사한다.
#
# **정답:** ①, ②, ③, ④
#
# **해설:** 코드 전에 데이터 구조와 IPO, 제외 범위, 테스트 예상 결과를 정하는 것이 좋습니다.
#
# ---
